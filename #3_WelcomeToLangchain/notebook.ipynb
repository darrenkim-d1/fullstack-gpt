# %%
a = 2
b = 4

c = a+b

c
# Out:
# 6

# %%
#from langchain.llms.openai import OpenAI
from langchain.chat_models import ChatOpenAI

#llm = OpenAI()
chat = ChatOpenAI()

#a = llm.predict("한국어도 인식이 되나?")
b = chat.predict("세계에는 몇개의 나라가 있어?")

b
# Out:
# '현재 세계에는 195개의 나라가 있습니다.'
