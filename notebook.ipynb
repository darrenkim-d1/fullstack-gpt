# %%
a = 2
b = 4

c = a+b

c
# Out:
# 6

# %%
#from langchain.llms.openai import OpenAI
from langchain.chat_models import ChatOpenAI

#llm = OpenAI()
chat = ChatOpenAI()

#a = llm.predict("한국어도 인식이 되나?")
b = chat.predict("How Manu Contries Are There in the World?")

b
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[4], line 8
#       5 chat = ChatOpenAI()
#       7 #a = llm.predict("한국어도 인식이 되나?")
# ----> 8 b = chat.predict("How Manu Contries Are There in the World?")
#      10 a, b
#
# File ~/repository/fullstack-gpt/env/lib/python3.11/site-packages/langchain/chat_models/base.py:636, in BaseChatModel.predict(self, text, stop, **kwargs)
#     634 else:
#     635     _stop = list(stop)
# --> 636 result = self([HumanMessage(content=text)], stop=_stop, **kwargs)
#     637 if isinstance(result.content, str):
#     638     return result.content
#
# File ~/repository/fullstack-gpt/env/lib/python3.11/site-packages/langchain/chat_models/base.py:600, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     593 def __call__(
#     594     self,
#     595     messages: List[BaseMessage],
#    (...)
# ...
