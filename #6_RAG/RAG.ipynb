# %%
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import TextLoader

__loader__ = TextLoader("../files/chapter_01.txt")

__loader__.load()

# %%
from langchain.document_loaders import PyPDFLoader

__loader__ = PyPDFLoader("../files/chapter_01.pdf")

__loader__.load()

# %%
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

splitter1 = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=50)

loader= UnstructuredFileLoader("../files/chapter_01.pdf")

loader.load_and_split(text_splitter=splitter1)

# %%
from langchain.text_splitter import CharacterTextSplitter

splitter2 = CharacterTextSplitter(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100
)

loader.load_and_split(text_splitter=splitter2)

# %%
from langchain.embeddings import OpenAIEmbeddings, CacheBackedEmbeddings
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.storage import LocalFileStore

cache_dir = LocalFileStore("../.cache/")

splitter2 = CharacterTextSplitter(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100
)

embedder = OpenAIEmbeddings()

vector = embedder.embed_query("Hi")

len(vector)

loader = UnstructuredFileLoader("../files/chapter_01.pdf")

docs = loader.load_and_split(text_splitter=splitter2)

embeddings = OpenAIEmbeddings()

chaced_embeddings = CacheBackedEmbeddings.from_bytes_store(embeddings, cache_dir)

vectorstore = Chroma.from_documents(docs, chaced_embeddings)

# %%
result = vectorstore.similarity_search("where dows winston live")

len(result)
result
